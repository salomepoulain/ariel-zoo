# %%
from ariel_experiments.utils.initialize import generate_random_individual

from ariel_experiments.gui_vis.view_mujoco import view

view(generate_random_individual(), return_img=True, remove_background=True, tilted=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=164x122>
