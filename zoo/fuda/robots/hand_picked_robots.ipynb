# %%
import canonical_toolkit as ctk

# %% [markdown]
# ### BabyA

# %%
baby_a = ctk.node_from_string('C[b(H2B)f(H2H2BH2B)r(HBHB[rl(H2B)])]')

# %%
baby_a.shift_visual_rotation(1)
ctk.quick_view(baby_a.to_graph())
print(baby_a.canonicalize(limb_order=False).to_string())
print(baby_a.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=374x287>
# C[r(H2B)l(H2H2BH2B)f(HBHB[rl(H2B)])]
# C[b(H2B)f(H2H2BH2B)r(HBHB[rl(H2B)])]

# %%
baby_a_aligned = "C[f(H2B)b(H2H2BH2B)l(HBHB[rl(H2B)])]"

# %% [markdown]
# ### BabyB

# %%
baby_b = ctk.node_from_string('C[f(H2B)brl(HBH2BH2B)]')

# %%
baby_b.shift_visual_rotation(1)
ctk.quick_view(baby_b.to_graph())
print(baby_b.canonicalize(limb_order=False).to_string())
print(baby_b.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=510x304>
# C[l(H2B)fbr(HBH2BH2B)]
# C[f(H2B)brl(HBH2BH2B)]

# %%
baby_b_aligned = "C[l(H2B)fbr(HBH2BH2B)]"

# %% [markdown]
# ### Blokky

# %% [markdown]
# canonical brick flaw, in terms of attachment points?

# %%
blokky = ctk.node_from_string('C[f(H)l(B[r(H)]HH2B6[r(B)]B[r(BB[lr(B)]B[r(B[l(H2)]B)])])]')

# %%
blokky.shift_visual_rotation(1)
ctk.quick_view(blokky.to_graph())
print(blokky.canonicalize(limb_order=False).to_string())
print(blokky.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=291x242>
# C[b(B[r(H)]HH2B[t(B)]B[t(BB[tb(B)]B[t(B[b(H)]B)])])l(H)]
# C[f(B[r(H)]HH2B[t(B)]B[t(BB[tb(B)]B[t(B[b(H)]B)])])r(H)]

# %%
blokky_aligned = "C[b(B[r(H)]HH2B[t(B)]B[t(BB[tb(B)]B[t(B[b(H)]B)])])l(H)]"

# %% [markdown]
# ### Garrix

# %%
garrix = ctk.node_from_string('C[b(H)r(HHH2B[b(HB[b(H2)t(HH2H2B)]H2)]B)]')

# %%
garrix.shift_visual_rotation(1)
ctk.quick_view(garrix.to_graph())
print(garrix.canonicalize(limb_order=False).to_string())
print(garrix.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=344x231>
# C[r(H)f(HHH2B[b(HB[b(H2)t(HH2H2B)]H2)]B)]
# C[b(H)r(HHH2B[b(HB[b(H2)t(HH2H2B)]H2)]B)]

# %%
garrix_aligned = "C[r(H)f(HHH2B[b(HB[b(H2)t(HH2H2B)]H2)]B)]"

# %% [markdown]
# ### Gecko

# %%
gecko = ctk.node_from_string('C[l(H2B)r(H2B)f(HBHB[l(H2B)r(H2B)])]')

# %%
gecko.shift_visual_rotation(1)
ctk.quick_view(gecko.to_graph())
print(gecko.canonicalize(limb_order=False).to_string())
print(gecko.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=374x234>
# C[fb(H2B)l(HBHB[rl(H2B)])]
# C[fb(H2B)r(HBHB[rl(H2B)])]

# %%
gecko_aligned = "C[fb(H2B)l(HBHB[rl(H2B)])]"

# %% [markdown]
# ### Insect

# %%
insect = ctk.node_from_string('C[l(HH2B6[r(H2)l(HB[r(H2HH2)]H)]H)]')

# %%
insect.shift_visual_rotation(1)
ctk.quick_view(insect.to_graph())
print(insect.canonicalize(limb_order=False).to_string())
print(insect.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=376x155>
# C[b(HH2B[t(H)b(H2B[r(H2HH2)]H)]H2)]
# C[r(HH2B[t(H)b(H2B[r(H2HH2)]H)]H2)]

# %%
insect_aligned = "C[b(HH2B[t(H)b(H2B[r(H2HH2)]H)]H2)]"

# %% [markdown]
# ### Linkin

# %%
linkin = ctk.node_from_string('C[b(H2)r(HHHH2B[t(H2H2HH2H)b(HH)]B)]')

# %%
linkin.shift_visual_rotation(1)
ctk.quick_view(linkin.to_graph())
print(linkin.canonicalize(limb_order=False).to_string())
print(linkin.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=357x300>
# C[r(H2)f(HHHH2B[t(H2H2HH2H)b(HH)]B)]
# C[b(H2)r(HHHH2B[t(H2H2HH2H)b(HH)]B)]

# %%
linkin_aligned = "C[l(H2)b(HHHH2B[t(H2H2HH2H)b(HH)]B)]"

# %% [markdown]
# ### Longleg

# %%
longleg = ctk.node_from_string('C[l(HHHH2HB6[l(HH2B6[r(H)l(HH)])r(H2)]H2)]')

# %%
longleg.shift_visual_rotation(1)
ctk.quick_view(longleg.to_graph())
print(longleg.canonicalize(limb_order=False).to_string())
print(longleg.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=443x207>
# C[b(HHHH2HB[t(H)b(H2H2B[t(H2)b(H2H)])]H)]
# C[r(HHHH2HB[t(H)b(H2H2B[t(H2)b(H2H)])]H)]

# %%
longleg_aligned = "C[f(HHHH2HB[t(H)b(H2H2B[t(H2)b(H2H)])]H)]"

# %% [markdown]
# ### Penguin

# %%
penguin = ctk.node_from_string('C[l(B[l(HH2B6[r(H2)l(HH2H2B4[r(H2HH2B[r(H)l(BH)])]HB)])])]')

# %%
penguin.shift_visual_rotation(1)
ctk.quick_view(penguin.to_graph())
print(penguin.canonicalize(limb_order=False).to_string())
print(penguin.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=325x301>
# C[b(B[l(HH2B[t(H)b(H2H2H2B[l(H2HH2B[r(BH)l(H)])]HB)])])]
# C[r(B[l(HH2B[t(H)b(H2H2H2B[l(H2HH2B[r(BH)l(H)])]HB)])])]

# %%
penguin_aligned = "C[f(B[l(HH2B[t(H)b(H2H2H2B[l(H2HH2B[r(BH)l(H)])]HB)])])]"

# %% [markdown]
# ### Pentapod

# %%
pentapod = ctk.node_from_string('C[l(HHHH2B6[l(H2)]HB[l(B)r(H2)]HB[lr(H2)])]')

# %%
pentapod.shift_visual_rotation(1)
ctk.quick_view(pentapod.to_graph())
print(pentapod.canonicalize(limb_order=False).to_string())
print(pentapod.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=450x259>
# C[b(HHHH2B[b(H)]H2B[r(B)l(H2)]HB[rl(H2)])]
# C[r(HHHH2B[b(H)]H2B[r(B)l(H2)]HB[rl(H2)])]

# %%
pentapod_aligned = "C[b(HHHH2B[b(H)]H2B[r(B)l(H2)]HB[rl(H2)])]"

# %% [markdown]
# ### Queen

# %%
queen = ctk.node_from_string('C[b(H)r(HHH2B6[l(H2)r(B[r(BHH)]B[rl(H2)])])]')

# %%
queen.shift_visual_rotation(1)
ctk.quick_view(queen.to_graph())
print(queen.canonicalize(limb_order=False).to_string())
print(queen.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=282x249>
# C[r(H)f(HHH2B[t(B[t(BH2H)]B[tb(H)])b(H)])]
# C[b(H)r(HHH2B[t(B[t(BH2H)]B[tb(H)])b(H)])]

# %%
queen_aligned = "C[l(H)b(HHH2B[t(B[t(BH2H)]B[tb(H)])b(H)])]"

# %% [markdown]
# ### Salamander

# %%
salamander = ctk.node_from_string('C[l(H2)r(HH2)f(HB[l(H2)]B[l(H2)]HB[l(H2B6[l(B)]HH2)]B[l(H2)]B[l(H2)]BHB[l(B)]H)]')

# %%
salamander.shift_visual_rotation(1)
ctk.quick_view(salamander.to_graph())
print(salamander.canonicalize(limb_order=False).to_string())
print(salamander.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=486x298>
# C[b(H2)l(HB[l(H2)]B[l(H2)]HB[l(H2B[b(B)]H2H2)]B[l(H2)]B[l(H2)]BHB[l(B)]H)f(HH2)]
# C[l(H2)f(HB[l(H2)]B[l(H2)]HB[l(H2B[b(B)]H2H2)]B[l(H2)]B[l(H2)]BHB[l(B)]H)r(HH2)]

# %%
salamander_aligned = "C[b(H2)l(HB[l(H2)]B[l(H2)]HB[l(H2B[b(B)]H2H2)]B[l(H2)]B[l(H2)]BHB[l(B)]H)f(HH2)]"

# %% [markdown]
# ### Snake

# %% [markdown]
# camera issue

# %%
snake = ctk.node_from_string('C[f(H2BH2BH2BH2BH2BH2BH2BH2)]')

# %%
snake.shift_visual_rotation(1)
ctk.quick_view(snake.to_graph())
print(snake.canonicalize(limb_order=False).to_string())
print(snake.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=514x312>
# C[l(H2BH2BH2BH2BH2BH2BH2BH2)]
# C[r(H2BH2BH2BH2BH2BH2BH2BH2)]

# %%
snake_aligned = "C[f(H2BH2BH2BH2BH2BH2BH2BH2)]"

# %% [markdown]
# ### Spider

# %%
spider = ctk.node_from_string('C[lfrb(HBH2B)]')

# %%
spider.shift_visual_rotation(1)
ctk.quick_view(spider.to_graph())
print(spider.canonicalize(limb_order=False).to_string())
print(spider.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=374x234>
# C[4-(HBH2B)]
# C[4-(HBH2B)]

# %%
spider_aligned = "C[4-(HBH2B)]"

# %% [markdown]
# ### Squarish

# %%
squarish = ctk.node_from_string('C[f(H2B6[l(HB[l(B[r(HB[l(B[l(B)])])]H2)])]H2)]')

# %%
squarish.shift_visual_rotation(1)
ctk.quick_view(squarish.to_graph())
print(squarish.canonicalize(limb_order=False).to_string())
print(squarish.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=298x190>
# C[l(H2B[b(H2B[l(B[r(HB[l(B[l(B)])])]H2)])]H)]
# C[r(H2B[b(H2B[l(B[r(HB[l(B[l(B)])])]H2)])]H)]

# %%
squarish_aligned = "C[l(H2B[b(H2B[l(B[r(HB[l(B[l(B)])])]H2)])]H)]"

# %% [markdown]
# ### Stingray

# %%
stingray = ctk.node_from_string('C[r(H)f(HH2B6[l(H2)r(B)]B[r(H)l(H2B6[r(H)]H2B)]H)]')

# %%
stingray.shift_visual_rotation(1)
ctk.quick_view(stingray.to_graph())
print(stingray.canonicalize(limb_order=False).to_string())
print(stingray.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=274x242>
# C[f(H)l(HH2B[t(B)b(H)]B[t(H2)b(HB[b(H2)]HB)]H2)]
# C[b(H)r(HH2B[t(B)b(H)]B[t(H2)b(HB[b(H2)]HB)]H2)]

# %%
stingray_aligned = "C[l(H)b(HH2B[t(B)b(H)]B[t(H2)b(HB[b(H2)]HB)]H2)]"

# %% [markdown]
# ### Tinlicker

# %%
tinlicker = ctk.node_from_string('C[l(HHHH2B6[l(B[r(B[l(B)]H2B6[r(B[r(H)])]H)]H)])]')

# %%
tinlicker.shift_visual_rotation(1)
ctk.quick_view(tinlicker.to_graph())
print(tinlicker.canonicalize(limb_order=False).to_string())
print(tinlicker.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=443x242>
# C[b(HHHH2B[b(B[b(B[b(B)]HB[t(B[t(H2)])]H2)]H2)])]
# C[r(HHHH2B[b(B[b(B[b(B)]HB[t(B[t(H2)])]H2)]H2)])]

# %%
tinlicker_aligned = "C[b(HHHH2B[b(B[b(B[b(B)]HB[t(B[t(H2)])]H2)]H2)])]"

# %% [markdown]
# ### Turtle

# %%
turtle = ctk.node_from_string('C[r(B[r(H2)l(HH2B6[l(H)r(H2B6[r(H2B6[r(H2)l(HH2HH)])l(HH2)]B)]B)])]')

# %%
turtle.shift_visual_rotation(1)
ctk.quick_view(turtle.to_graph())
print(turtle.canonicalize(limb_order=False).to_string())
print(turtle.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=382x226>
# C[f(B[r(H2)l(HH2B[b(H2)t(HB[b(H2H2)t(HB[t(H)b(H2H2HH)])]B)]B)])]
# C[r(B[r(H2)l(HH2B[b(H2)t(HB[b(H2H2)t(HB[t(H)b(H2H2HH)])]B)]B)])]

# %%
turtle_aligned = "C[f(B[r(H2)l(HH2B[b(H2)t(HB[b(H2H2)t(HB[t(H)b(H2H2HH)])]B)]B)])]"

# %% [markdown]
# ### WW

# %%
ww = ctk.node_from_string('C[f(H)l(HHH2B6[l(H2B6[l(H2)]B[r(HB[l(HHH2)])])])]')

# %%
ww.shift_visual_rotation(1)
ctk.quick_view(ww.to_graph())
print(ww.canonicalize(limb_order=False).to_string())
print(ww.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=520x172>
# C[l(H)b(HHH2B[b(HB[t(H)]B[b(H2B[r(HHH2)])])])]
# C[b(H)r(HHH2B[b(HB[t(H)]B[b(H2B[r(HHH2)])])])]

# %%
ww_aligned = "C[l(H)b(HHH2B[b(HB[t(H)]B[b(H2B[r(HHH2)])])])]"

# %% [markdown]
# ### Zappa

# %%
zappa = ctk.node_from_string('C[f(H2)l(HHHH2HB6[l(HB[l(H2B)]H2)]H2H)]')

# %%
zappa.shift_visual_rotation(1)
ctk.quick_view(zappa.to_graph())
print(zappa.canonicalize(limb_order=False).to_string())
print(zappa.copy().canonicalize().to_string())
# Out:
# <PIL.Image.Image image mode=RGBA size=425x219>
# C[l(H2)b(HHHH2HB[b(H2B[l(H2B)]H2)]HH)]
# C[b(H2)r(HHHH2HB[b(H2B[l(H2B)]H2)]HH)]

# %%
zappa_aligned = "C[l(H2)b(HHHH2HB[b(H2B[l(H2B)]H2)]HH)]"

# %% [markdown]
# ---

# %%
import pandas as pd

all_robots = {
    "baby_a": baby_a_aligned,
    "baby_b": baby_b_aligned,
    "blokky": blokky_aligned,
    "garrix": garrix_aligned,
    "gecko": gecko_aligned,
    "insect": insect_aligned,
    "linkin": linkin_aligned,
    "longleg": longleg_aligned,
    "penguin": penguin_aligned,
    "pentapod": pentapod_aligned,
    "queen": queen_aligned,
    "salamander": salamander_aligned,
    "snake": snake_aligned,
    "spider": spider_aligned,
    "squarish": squarish_aligned,
    "stingray": stingray_aligned,
    "tinlicker": tinlicker_aligned,
    "turtle": turtle_aligned,
    "ww": ww_aligned,
    "zappa": zappa_aligned,
}

hand_picked = {
    "spider": spider_aligned,
    "gecko": gecko_aligned,
    "baby_a": baby_a_aligned,
    "baby_b": baby_b_aligned,
    "snake": snake_aligned,
}

all_df = pd.DataFrame({
    "trivial_name": list(all_robots.keys()),
    "fuda_aligned": list(all_robots.values()),
    "canonical": [ctk.node_from_string(robot).canonicalize().to_string() for robot in all_robots.values()]
})
all_df.to_csv('all_fuda.csv', index=False)

hand_picked_df = pd.DataFrame({
    "trivial_name": list(hand_picked.keys()),
    "fuda_aligned": list(hand_picked.values()),
    "canonical": [ctk.node_from_string(robot).canonicalize().to_string() for robot in hand_picked.values()]
})
hand_picked_df.to_csv('hand_picked.csv', index=False)

# %%
ctk.snapshot_saver([ctk.node_from_string(robot).to_graph() for robot in all_robots.values()], save_folder="__data__/snapshots/all")
ctk.snapshot_saver([ctk.node_from_string(robot).to_graph() for robot in hand_picked.values()], save_folder="__data__/snapshots/hand_picked")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved 20/20 snapshots to __data__/snapshots/all
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved 5/5 snapshots to __data__/snapshots/hand_picked

# %%
ctk.snapshot_saver([ctk.node_from_string(robot).to_graph() for robot in all_robots.values()], save_folder="__data__/snapshots/all")

hand_picked_plotter = ctk.GridPlotter()
hand_picked_plotter.add_image_data(data_folder="__data__/snapshots/hand_picked", shape=(1, 5))
hand_picked_plotter[:,:].set_title(None)
hand_picked_plotter.plot()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved 20/20 snapshots to __data__/snapshots/all

# %%
all_plotter = ctk.GridPlotter()
all_plotter.add_image_data(data_folder="__data__/snapshots/all", shape=(4, 5))
all_plotter[:,:].set_title(None)
all_plotter.plot()
